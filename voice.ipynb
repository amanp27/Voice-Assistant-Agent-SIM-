# %%
import secrets

# %%
print(secrets.token_hex(16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(secrets.token_hex(16))
#
# NameError: name 'secrets' is not defined
